# %%
import numpy
import random
from time import time
import pandas as pd
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession
from pyspark.sql import Row
from os.path import expanduser, join, abspath
from pyspark.sql.functions import col
from sklearn.metrics import roc_curve, precision_recall_curve, auc
from pyspark.sql import functions as F
from pyspark.sql.functions import udf

from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoder, VectorAssembler
from pyspark.ml.feature import OneHotEncoderEstimator
from pyspark.sql.functions import col, asc
from pyspark.ml.feature import MinMaxScaler

from pyspark.sql import SparkSession
from pyspark.sql import Row

from matplotlib import cm
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import os
import sys
from pyspark.sql import *
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession

from pysparkling import *
import h2o
# Out:
# PySparkling is using internally bundled H2O of version 3.24.0.1, but H2O installed in the python environment is of version 3.24.0.5.

# %%
sc
# Out:
# <SparkContext master=yarn appName=PySparkShell>

# %%
#Fetch data
feature_query="select * from grp_gdoop_clv_db.keep_cdf_final_features_t365d where record_date = '2018-06-12'"

df_features=spark.sql(feature_query)
df_features = df_features.filter(df_features.is_activation_x == 1).sample(False,0.01,301913)

df_features.cache()

print(df_features.count())
# Out:
# 61116

# %%
df_features.groupby("most_recent_l1_cat_x","most_recent_l2_cat_x").count().show()
# Out:
# +--------------------+--------------------+-----+
# |most_recent_l1_cat_x|most_recent_l2_cat_x|count|
# +--------------------+--------------------+-----+
# |          L1 - Local|    L2 - Home & Auto| 4168|
# |          L1 - Local|               other|    4|
# |          L1 - Local|L2 - Things to Do...| 2371|
# |          L1 - Local|L2 - Things to Do...|17012|
# |          L1 - Local|   L2 - Food & Drink| 6964|
# |         L1 - Travel|              Travel| 1661|
# |       L1 - Shopping|            Shopping|11462|
# |               Local|               other|   33|
# |          L1 - Local|         L2 - Retail| 7732|
# |          L1 - Local|L2 - Health / Bea...| 9708|
# |               other|               other|    1|
# +--------------------+--------------------+-----+

# %%
target_query="select * from grp_gdoop_clv_db.temp_deact_target_t365d"

df_target=spark.sql(target_query)

df_target.cache()
df_target.groupby("deactivated").count().show()
# Out:
# +-----------+--------+
# |deactivated|   count|
# +-----------+--------+
# |          1| 3262913|
# |          0|11493143|
# +-----------+--------+

# %%
tf = df_features.alias('tf')
tt = df_target.alias('tt')

training_data = tf.join(tt, "consumer_id" ,how='left_outer') 

training_data=training_data.fillna(1,subset="deactivated").drop("consumer_id","is_activation","is_reactivation_x","brand","record_date")

# need to fix queries and then remove
training_data = training_data.filter(training_data.most_recent_l2_cat_x != 'other')

training_data.cache()
# Out:
# DataFrame[recency_9block_cat_x: string, frequency_9block_cat_x: string, tenure_days_x: int, recency_x: int, frequency_t24m_x: bigint, nob_t24m_x: double, gp_t24m_x: double, frequency_t12m_x: bigint, nob_t12m_x: double, gp_t12m_x: double, local_orders_t24m_x: bigint, shopping_orders_t24m_x: bigint, travel_orders_t24m_x: bigint, app_orders_t24m_x: bigint, touch_orders_t24m_x: bigint, web_orders_t24m_x: bigint, most_recent_l1_cat_x: string, most_recent_l2_cat_x: string, most_recent_promo_type_cat_x: string, most_recent_platform_cat_x: string, is_activation_x: int, unique_purchase_quarters_t24m_x: bigint, visit_recency_x: int, visit_freq_7d_x: bigint, visit_freq_14_28d_x: bigint, visit_freq_28_60d_x: bigint, visit_freq_60_120d_x: bigint, visit_freq_120_180d_x: bigint, visit_freq_180_365d_x: bigint, appengaged_flag90d_x: int, webengaged_flag90d_x: int, touchengaged_flag90d_x: int, send_recency_x: int, sends_7d_x: bigint, sends_30d_x: bigint, open_recency_x: int, uniq_3day_opens_7d_x: bigint, uniq_3day_opens_30d_x: bigint, click_recency_x: int, uniq_3day_clicks_7d_x: bigint, uniq_3day_clicks_30d_x: bigint, unsubscription_30d_x: bigint, fnd_inv_csi_x: decimal(10,4), hbw_inv_csi_x: decimal(10,4), hna_inv_csi_x: decimal(10,4), retail_inv_csi_x: decimal(10,4), ttd_inv_csi_x: decimal(10,4), charity_inv_csi_x: decimal(10,4), total_inv_csi_x: decimal(10,4), age_x: int, gender_cat_x: string, marital_status_cat_x: string, email_contactable_x: int, mobile_contactable_x: int, deactivated: int]

# %%
training_data.groupby("deactivated").count().show()
# Out:
# +-----------+-----+
# |deactivated|count|
# +-----------+-----+
# |          1|52124|
# |          0| 8954|
# +-----------+-----+

# %%
import pandas as pd
pd.DataFrame(training_data.take(5), columns=training_data.columns).transpose()
# Out:
#                                                         0  \
# recency_9block_cat_x             3-Low Rec (121-365 Days)
# frequency_9block_cat_x               1-Low Freq (1 Order)
# tenure_days_x                                         270
# recency_x                                             270
# frequency_t24m_x                                        1
# nob_t24m_x                                         208.99
# gp_t24m_x                                             -10
# frequency_t12m_x                                        1
# nob_t12m_x                                         208.99
# gp_t12m_x                                        -10.3868
# local_orders_t24m_x                                     0
# shopping_orders_t24m_x                                  1
# travel_orders_t24m_x                                    0
# app_orders_t24m_x                                       0
# touch_orders_t24m_x                                     0
# web_orders_t24m_x                                       1
# most_recent_l1_cat_x                        L1 - Shopping
# most_recent_l2_cat_x                             Shopping
# most_recent_promo_type_cat_x                  NO DISCOUNT
# most_recent_platform_cat_x                            web
# is_activation_x                                         1
# unique_purchase_quarters_t24m_x                         1
# visit_recency_x                                       270
# visit_freq_7d_x                                         0
# visit_freq_14_28d_x                                     0
# visit_freq_28_60d_x                                     0
# visit_freq_60_120d_x                                    0
# visit_freq_120_180d_x                                   0
# visit_freq_180_365d_x                                   5
# appengaged_flag90d_x                                    0
# webengaged_flag90d_x                                    0
# touchengaged_flag90d_x                                  0
# send_recency_x                                         99
# sends_7d_x                                              0
# sends_30d_x                                             0
# open_recency_x                                         99
# uniq_3day_opens_7d_x                                    0
# uniq_3day_opens_30d_x                                   0
# click_recency_x                                        99
# uniq_3day_clicks_7d_x                                   0
# uniq_3day_clicks_30d_x                                  0
# unsubscription_30d_x                                    0
# fnd_inv_csi_x                                      0.3268
# hbw_inv_csi_x                                      7.7719
# hna_inv_csi_x                                      1.2138
# retail_inv_csi_x                                   0.0000
# ttd_inv_csi_x                                      2.0685
# charity_inv_csi_x                                  0.0000
# total_inv_csi_x                                   11.3810
# age_x                                                  38
# gender_cat_x                                            U
# marital_status_cat_x                                   1M
# email_contactable_x                                     0
# mobile_contactable_x                                    0
# deactivated                                             1
#
#                                                            1  \
# recency_9block_cat_x                3-Low Rec (121-365 Days)
# frequency_9block_cat_x                  1-Low Freq (1 Order)
# tenure_days_x                                            312
# recency_x                                                312
# frequency_t24m_x                                           1
# nob_t24m_x                                                40
# gp_t24m_x                                             10.048
# frequency_t12m_x                                           1
# nob_t12m_x                                                40
# gp_t12m_x                                             10.048
# local_orders_t24m_x                                        1
# shopping_orders_t24m_x                                     0
# travel_orders_t24m_x                                       0
# app_orders_t24m_x                                          1
# touch_orders_t24m_x                                        0
# web_orders_t24m_x                                          0
# most_recent_l1_cat_x                              L1 - Local
# most_recent_l2_cat_x             L2 - Things to Do - Leisure
# most_recent_promo_type_cat_x                     NO DISCOUNT
# most_recent_platform_cat_x                               app
# is_activation_x                                            1
# unique_purchase_quarters_t24m_x                            1
# visit_recency_x                                          900
# visit_freq_7d_x                                            0
# visit_freq_14_28d_x                                        0
# visit_freq_28_60d_x                                        0
# visit_freq_60_120d_x                                       0
# visit_freq_120_180d_x                                      0
# visit_freq_180_365d_x                                      0
# appengaged_flag90d_x                                       0
# webengaged_flag90d_x                                       0
# touchengaged_flag90d_x                                     0
# send_recency_x                                             0
# sends_7d_x                                                32
# sends_30d_x                                              123
# open_recency_x                                            27
# uniq_3day_opens_7d_x                                       0
# uniq_3day_opens_30d_x                                      1
# click_recency_x                                           99
# uniq_3day_clicks_7d_x                                      0
# uniq_3day_clicks_30d_x                                     0
# unsubscription_30d_x                                       0
# fnd_inv_csi_x                                         6.7695
# hbw_inv_csi_x                                        65.9888
# hna_inv_csi_x                                        11.9933
# retail_inv_csi_x                                      3.6700
# ttd_inv_csi_x                                        44.6872
# charity_inv_csi_x                                     0.0000
# total_inv_csi_x                                     133.1088
# age_x                                                     38
# gender_cat_x                                               U
# marital_status_cat_x                                      1M
# email_contactable_x                                        1
# mobile_contactable_x                                       0
# deactivated                                                1
#
#                                                        2  \
# recency_9block_cat_x             2-Med Rec (31-120 Days)
# frequency_9block_cat_x              1-Low Freq (1 Order)
# tenure_days_x                                        102
# recency_x                                            102
# frequency_t24m_x                                       1
# nob_t24m_x                                         28.98
# gp_t24m_x                                         5.4763
# frequency_t12m_x                                       1
# nob_t12m_x                                         28.98
# gp_t12m_x                                         5.4763
# local_orders_t24m_x                                    0
# shopping_orders_t24m_x                                 1
# travel_orders_t24m_x                                   0
# app_orders_t24m_x                                      1
# touch_orders_t24m_x                                    0
# web_orders_t24m_x                                      0
# most_recent_l1_cat_x                       L1 - Shopping
# most_recent_l2_cat_x                            Shopping
# most_recent_promo_type_cat_x                 NO DISCOUNT
# most_recent_platform_cat_x                           app
# is_activation_x                                        1
# unique_purchase_quarters_t24m_x                        1
# visit_recency_x                                      900
# visit_freq_7d_x                                        0
# visit_freq_14_28d_x                                    0
# visit_freq_28_60d_x                                    0
# visit_freq_60_120d_x                                   0
# visit_freq_120_180d_x                                  0
# visit_freq_180_365d_x                                  0
# appengaged_flag90d_x                                   0
# webengaged_flag90d_x                                   0
# touchengaged_flag90d_x                                 0
# send_recency_x                                        99
# sends_7d_x                                             0
# sends_30d_x                                            0
# open_recency_x                                        99
# uniq_3day_opens_7d_x                                   0
# uniq_3day_opens_30d_x                                  0
# click_recency_x                                       99
# uniq_3day_clicks_7d_x                                  0
# uniq_3day_clicks_30d_x                                 0
# unsubscription_30d_x                                   0
# fnd_inv_csi_x                                     4.0000
# hbw_inv_csi_x                                    35.0000
# hna_inv_csi_x                                     6.0000
# retail_inv_csi_x                                  1.6900
# ttd_inv_csi_x                                    20.0000
# charity_inv_csi_x                                 0.0000
# total_inv_csi_x                                  66.6900
# age_x                                                 38
# gender_cat_x                                           U
# marital_status_cat_x                                  1M
# email_contactable_x                                    0
# mobile_contactable_x                                   0
# deactivated                                            1
#
#                                                            3  \
# recency_9block_cat_x                3-Low Rec (121-365 Days)
# frequency_9block_cat_x                  1-Low Freq (1 Order)
# tenure_days_x                                            330
# recency_x                                                330
# frequency_t24m_x                                           1
# nob_t24m_x                                                18
# gp_t24m_x                                             8.5716
# frequency_t12m_x                                           1
# nob_t12m_x                                                18
# gp_t12m_x                                             8.5716
# local_orders_t24m_x                                        1
# shopping_orders_t24m_x                                     0
# travel_orders_t24m_x                                       0
# app_orders_t24m_x                                          0
# touch_orders_t24m_x                                        0
# web_orders_t24m_x                                          1
# most_recent_l1_cat_x                              L1 - Local
# most_recent_l2_cat_x             L2 - Things to Do - Leisure
# most_recent_promo_type_cat_x                     NO DISCOUNT
# most_recent_platform_cat_x                               web
# is_activation_x                                            1
# unique_purchase_quarters_t24m_x                            1
# visit_recency_x                                          230
# visit_freq_7d_x                                            0
# visit_freq_14_28d_x                                        0
# visit_freq_28_60d_x                                        0
# visit_freq_60_120d_x                                       0
# visit_freq_120_180d_x                                      0
# visit_freq_180_365d_x                                     14
# appengaged_flag90d_x                                       0
# webengaged_flag90d_x                                       0
# touchengaged_flag90d_x                                     0
# send_recency_x                                            99
# sends_7d_x                                                 0
# sends_30d_x                                                0
# open_recency_x                                            99
# uniq_3day_opens_7d_x                                       0
# uniq_3day_opens_30d_x                                      0
# click_recency_x                                           99
# uniq_3day_clicks_7d_x                                      0
# uniq_3day_clicks_30d_x                                     0
# unsubscription_30d_x                                       0
# fnd_inv_csi_x                                         2.8675
# hbw_inv_csi_x                                        58.4803
# hna_inv_csi_x                                         6.2834
# retail_inv_csi_x                                      2.0129
# ttd_inv_csi_x                                        18.6013
# charity_inv_csi_x                                     0.0000
# total_inv_csi_x                                      88.2454
# age_x                                                     38
# gender_cat_x                                               U
# marital_status_cat_x                                      1M
# email_contactable_x                                        0
# mobile_contactable_x                                       0
# deactivated                                                1
#
#                                                         4
# recency_9block_cat_x             3-Low Rec (121-365 Days)
# frequency_9block_cat_x               1-Low Freq (1 Order)
# tenure_days_x                                         217
# recency_x                                             217
# frequency_t24m_x                                        1
# nob_t24m_x                                              5
# gp_t24m_x                                           4.756
# frequency_t12m_x                                        1
# nob_t12m_x                                              5
# gp_t12m_x                                           4.756
# local_orders_t24m_x                                     1
# shopping_orders_t24m_x                                  0
# travel_orders_t24m_x                                    0
# app_orders_t24m_x                                       1
# touch_orders_t24m_x                                     0
# web_orders_t24m_x                                       0
# most_recent_l1_cat_x                           L1 - Local
# most_recent_l2_cat_x                          L2 - Retail
# most_recent_promo_type_cat_x                  NO DISCOUNT
# most_recent_platform_cat_x                            app
# is_activation_x                                         1
# unique_purchase_quarters_t24m_x                         1
# visit_recency_x                                        99
# visit_freq_7d_x                                         0
# visit_freq_14_28d_x                                     0
# visit_freq_28_60d_x                                     0
# visit_freq_60_120d_x                                   42
# visit_freq_120_180d_x                                   0
# visit_freq_180_365d_x                                   0
# appengaged_flag90d_x                                    0
# webengaged_flag90d_x                                    0
# touchengaged_flag90d_x                                  0
# send_recency_x                                         99
# sends_7d_x                                              0
# sends_30d_x                                             0
# open_recency_x                                         99
# uniq_3day_opens_7d_x                                    0
# uniq_3day_opens_30d_x                                   0
# click_recency_x                                        99
# uniq_3day_clicks_7d_x                                   0
# uniq_3day_clicks_30d_x                                  0
# unsubscription_30d_x                                    0
# fnd_inv_csi_x                                      0.0000
# hbw_inv_csi_x                                      1.4592
# hna_inv_csi_x                                      0.1615
# retail_inv_csi_x                                   0.0265
# ttd_inv_csi_x                                      0.2759
# charity_inv_csi_x                                  0.0000
# total_inv_csi_x                                    1.9231
# age_x                                                  38
# gender_cat_x                                            U
# marital_status_cat_x                                   1M
# email_contactable_x                                     0
# mobile_contactable_x                                    0
# deactivated                                             1

# %%
trainingdf,validatedf = training_data.randomSplit([.5,.5],492382)

trainingdf.cache()
validatedf.cache()
trainingdf.printSchema()
# Out:
# root
#  |-- recency_9block_cat_x: string (nullable = true)
#  |-- frequency_9block_cat_x: string (nullable = true)
#  |-- tenure_days_x: integer (nullable = true)
#  |-- recency_x: integer (nullable = true)
#  |-- frequency_t24m_x: long (nullable = true)
#  |-- nob_t24m_x: double (nullable = true)
#  |-- gp_t24m_x: double (nullable = true)
#  |-- frequency_t12m_x: long (nullable = true)
#  |-- nob_t12m_x: double (nullable = true)
#  |-- gp_t12m_x: double (nullable = true)
#  |-- local_orders_t24m_x: long (nullable = true)
#  |-- shopping_orders_t24m_x: long (nullable = true)
#  |-- travel_orders_t24m_x: long (nullable = true)
#  |-- app_orders_t24m_x: long (nullable = true)
#  |-- touch_orders_t24m_x: long (nullable = true)
#  |-- web_orders_t24m_x: long (nullable = true)
#  |-- most_recent_l1_cat_x: string (nullable = true)
#  |-- most_recent_l2_cat_x: string (nullable = true)
#  |-- most_recent_promo_type_cat_x: string (nullable = true)
#  |-- most_recent_platform_cat_x: string (nullable = true)
#  |-- is_activation_x: integer (nullable = true)
#  |-- unique_purchase_quarters_t24m_x: long (nullable = true)
#  |-- visit_recency_x: integer (nullable = true)
#  |-- visit_freq_7d_x: long (nullable = true)
#  |-- visit_freq_14_28d_x: long (nullable = true)
#  |-- visit_freq_28_60d_x: long (nullable = true)
#  |-- visit_freq_60_120d_x: long (nullable = true)
#  |-- visit_freq_120_180d_x: long (nullable = true)
#  |-- visit_freq_180_365d_x: long (nullable = true)
#  |-- appengaged_flag90d_x: integer (nullable = true)
#  |-- webengaged_flag90d_x: integer (nullable = true)
#  |-- touchengaged_flag90d_x: integer (nullable = true)
#  |-- send_recency_x: integer (nullable = true)
#  |-- sends_7d_x: long (nullable = true)
#  |-- sends_30d_x: long (nullable = true)
#  |-- open_recency_x: integer (nullable = true)
#  |-- uniq_3day_opens_7d_x: long (nullable = true)
#  |-- uniq_3day_opens_30d_x: long (nullable = true)
#  |-- click_recency_x: integer (nullable = true)
#  |-- uniq_3day_clicks_7d_x: long (nullable = true)
#  |-- uniq_3day_clicks_30d_x: long (nullable = true)
#  |-- unsubscription_30d_x: long (nullable = true)
#  |-- fnd_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- hbw_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- hna_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- retail_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- ttd_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- charity_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- total_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- age_x: integer (nullable = true)
#  |-- gender_cat_x: string (nullable = true)
#  |-- marital_status_cat_x: string (nullable = true)
#  |-- email_contactable_x: integer (nullable = true)
#  |-- mobile_contactable_x: integer (nullable = true)
#  |-- deactivated: integer (nullable = true)

# %%
numeric_features = [t[0] for t in trainingdf.dtypes if t[1] != 'string']
trainingdf.select(numeric_features).describe().toPandas().transpose()
# Out:
#                                      0                     1  \
# summary                          count                  mean
# tenure_days_x                    30484    179.69646371867208
# recency_x                        30484    174.70289332108646
# frequency_t24m_x                 30484    1.0347723395879806
# nob_t24m_x                       30484     52.63257249704759
# gp_t24m_x                        30484    11.541916644797276
# frequency_t12m_x                 30484    1.0230612780475004
# nob_t12m_x                       30484     51.33778703582201
# gp_t12m_x                        30484    11.346563288938457
# local_orders_t24m_x              30484     0.803437869046057
# shopping_orders_t24m_x           30484   0.20309014565017713
# travel_orders_t24m_x             30484  0.028145912609893714
# app_orders_t24m_x                30484    0.3186917727332371
# touch_orders_t24m_x              30484    0.3731137645978218
# web_orders_t24m_x                30484   0.32813935179110354
# is_activation_x                  30484                   1.0
# unique_purchase_quarters_t24m_x  30484    1.0108253510038052
# visit_recency_x                  30484    144.37396667104053
# visit_freq_7d_x                  30484    0.5345427109303241
# visit_freq_14_28d_x              30484    0.9835979530245375
# visit_freq_28_60d_x              30484     2.313935179110353
# visit_freq_60_120d_x             30484     4.842113895814197
# visit_freq_120_180d_x            30484     4.093590080041989
# visit_freq_180_365d_x            30484     11.11625770896208
# appengaged_flag90d_x             30484    0.2661396142238551
# webengaged_flag90d_x             30484   0.16126492586274768
# touchengaged_flag90d_x           30484   0.20991339719196955
# send_recency_x                   30484     38.12534444298648
# sends_7d_x                       30484    16.124524340637713
# sends_30d_x                      30484     61.61064820889647
# open_recency_x                   30484     70.35057735205353
# uniq_3day_opens_7d_x             30484       1.0709224511219
# uniq_3day_opens_30d_x            30484      4.03864322267419
# click_recency_x                  30484     89.27932685999212
# uniq_3day_clicks_7d_x            30484   0.07006954467917596
# uniq_3day_clicks_30d_x           30484   0.24993439181209814
# unsubscription_30d_x             30484  0.013810523553339457
# fnd_inv_csi_x                    30484            5.39078163
# hbw_inv_csi_x                    30484           37.04173117
# hna_inv_csi_x                    30484            6.32916870
# retail_inv_csi_x                 30484            2.24531642
# ttd_inv_csi_x                    30484           25.45697816
# charity_inv_csi_x                30484                  0E-8
# total_inv_csi_x                  30484           76.46669029
# age_x                            30484     40.04687705025587
# email_contactable_x              30484    0.6554914053273848
# mobile_contactable_x             30484    0.2413397191969558
# deactivated                      30484    0.8570397585618685
#
#                                                    2          3         4
# summary                                       stddev        min       max
# tenure_days_x                     122.54160804994825          0      1167
# recency_x                         107.93731848382116          0       365
# frequency_t24m_x                  0.4251986928723138          1        33
# nob_t24m_x                         92.89785788326925       0.25    2000.0
# gp_t24m_x                         19.213254199957213      -10.0     400.0
# frequency_t12m_x                  0.2778193801067243          1        20
# nob_t12m_x                          79.6674537628344       0.25    1100.0
# gp_t12m_x                         18.998393653228543  -160.0773     400.0
# local_orders_t24m_x                0.507600588542376          0        26
# shopping_orders_t24m_x            0.4734761566411883          0        19
# travel_orders_t24m_x             0.16736403723198842          0         3
# app_orders_t24m_x                 0.5317992103736832          0        19
# touch_orders_t24m_x                0.511014527748095          0        10
# web_orders_t24m_x                 0.5016333935690498          0        10
# is_activation_x                                  0.0          1         1
# unique_purchase_quarters_t24m_x  0.15585202751905775          1         7
# visit_recency_x                    191.4436305395857          0       900
# visit_freq_7d_x                   2.5744348268825976          0        36
# visit_freq_14_28d_x                4.125081523428042          0        63
# visit_freq_28_60d_x                7.654390500802971          0       116
# visit_freq_60_120d_x              14.264043944477558          0       200
# visit_freq_120_180d_x             12.516152326946944          0       191
# visit_freq_180_365d_x             26.673254760620477          0       563
# appengaged_flag90d_x              0.4419453892961156          0         1
# webengaged_flag90d_x              0.3677811669035744          0         1
# touchengaged_flag90d_x            0.4072532425911144          0         1
# send_recency_x                     47.91819828581562          0        99
# sends_7d_x                        14.589025270864845          0        46
# sends_30d_x                        55.71497090190264          0       176
# open_recency_x                    42.602558610857336          0        99
# uniq_3day_opens_7d_x               3.813220560139954          0        37
# uniq_3day_opens_30d_x             13.734037031927663          0       121
# click_recency_x                   27.610157304849878          0        99
# uniq_3day_clicks_7d_x            0.39889340470556295          0         8
# uniq_3day_clicks_30d_x            1.0893963617172269          0        31
# unsubscription_30d_x             0.11670578302786835          0         1
# fnd_inv_csi_x                      6.101427325053541     0.0000   42.1136
# hbw_inv_csi_x                     24.483791151935687     0.0000  154.7243
# hna_inv_csi_x                     4.1423331113417055     0.0000   24.0000
# retail_inv_csi_x                  2.2641682919374384     0.0000   15.6109
# ttd_inv_csi_x                      21.49711071004584     0.0000  102.2619
# charity_inv_csi_x                                0.0     0.0000    0.0000
# total_inv_csi_x                    54.33758585973517     0.0000  302.9369
# age_x                              8.607517743217608         19        99
# email_contactable_x               0.4752155626789893          0         1
# mobile_contactable_x             0.42790286934406935          0         1
# deactivated                      0.35003804104864195          0         1

# %%
categorical_features = [t[0] for t in trainingdf.dtypes if t[1] == 'string']
trainingdf.select(categorical_features).describe().toPandas().transpose()
# Out:
#                                   0     1       2                       3  \
# summary                       count  mean  stddev                     min
# recency_9block_cat_x          30484  None    None  1-High Rec (0-30 Days)
# frequency_9block_cat_x        30484  None    None    1-Low Freq (1 Order)
# most_recent_l1_cat_x          30484  None    None              L1 - Local
# most_recent_l2_cat_x          30484  None    None       L2 - Food & Drink
# most_recent_promo_type_cat_x  30484  None    None                     ILS
# most_recent_platform_cat_x    30484  None    None                     app
# gender_cat_x                  30484  None    None                       F
# marital_status_cat_x          30484  None    None                      0U
#
#                                                      4
# summary                                            max
# recency_9block_cat_x          3-Low Rec (121-365 Days)
# frequency_9block_cat_x         3-High Freq (5+ Orders)
# most_recent_l1_cat_x                       L1 - Travel
# most_recent_l2_cat_x                            Travel
# most_recent_promo_type_cat_x                   organic
# most_recent_platform_cat_x                         web
# gender_cat_x                                         U
# marital_status_cat_x                                5U

# %%
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler
stages = []

for categoricalCol in categorical_features:
    stringIndexer = StringIndexer(inputCol = categoricalCol, outputCol = categoricalCol + 'Index')
    encoder = OneHotEncoderEstimator(inputCols=[stringIndexer.getOutputCol()], outputCols=[categoricalCol + "classVec"])
    stages += [stringIndexer, encoder]


# assemblerInputs = [c + "classVec" for c in categorical_features] + numeric_features
# assembler = VectorAssembler(inputCols=assemblerInputs, outputCol="features")
# stages += [assembler]

# %%
from pyspark.ml import Pipeline
pipeline = Pipeline(stages = stages)
pipelineModel = pipeline.fit(trainingdf)
trainingdf = pipelineModel.transform(trainingdf)
validatedf = pipelineModel.transform(validatedf)

# %%
# selectedCols = ['retained', 'features'] 
featureCols = numeric_features + [c + "classVec" for c in categorical_features]
training_final = trainingdf.select(featureCols)
validate_final = validatedf.select(featureCols)
training_final.printSchema()
# Out:
# root
#  |-- tenure_days_x: integer (nullable = true)
#  |-- recency_x: integer (nullable = true)
#  |-- frequency_t24m_x: long (nullable = true)
#  |-- nob_t24m_x: double (nullable = true)
#  |-- gp_t24m_x: double (nullable = true)
#  |-- frequency_t12m_x: long (nullable = true)
#  |-- nob_t12m_x: double (nullable = true)
#  |-- gp_t12m_x: double (nullable = true)
#  |-- local_orders_t24m_x: long (nullable = true)
#  |-- shopping_orders_t24m_x: long (nullable = true)
#  |-- travel_orders_t24m_x: long (nullable = true)
#  |-- app_orders_t24m_x: long (nullable = true)
#  |-- touch_orders_t24m_x: long (nullable = true)
#  |-- web_orders_t24m_x: long (nullable = true)
#  |-- is_activation_x: integer (nullable = true)
#  |-- unique_purchase_quarters_t24m_x: long (nullable = true)
#  |-- visit_recency_x: integer (nullable = true)
#  |-- visit_freq_7d_x: long (nullable = true)
#  |-- visit_freq_14_28d_x: long (nullable = true)
#  |-- visit_freq_28_60d_x: long (nullable = true)
#  |-- visit_freq_60_120d_x: long (nullable = true)
#  |-- visit_freq_120_180d_x: long (nullable = true)
#  |-- visit_freq_180_365d_x: long (nullable = true)
#  |-- appengaged_flag90d_x: integer (nullable = true)
#  |-- webengaged_flag90d_x: integer (nullable = true)
#  |-- touchengaged_flag90d_x: integer (nullable = true)
#  |-- send_recency_x: integer (nullable = true)
#  |-- sends_7d_x: long (nullable = true)
#  |-- sends_30d_x: long (nullable = true)
#  |-- open_recency_x: integer (nullable = true)
#  |-- uniq_3day_opens_7d_x: long (nullable = true)
#  |-- uniq_3day_opens_30d_x: long (nullable = true)
#  |-- click_recency_x: integer (nullable = true)
#  |-- uniq_3day_clicks_7d_x: long (nullable = true)
#  |-- uniq_3day_clicks_30d_x: long (nullable = true)
#  |-- unsubscription_30d_x: long (nullable = true)
#  |-- fnd_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- hbw_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- hna_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- retail_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- ttd_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- charity_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- total_inv_csi_x: decimal(10,4) (nullable = true)
#  |-- age_x: integer (nullable = true)
#  |-- email_contactable_x: integer (nullable = true)
#  |-- mobile_contactable_x: integer (nullable = true)
#  |-- deactivated: integer (nullable = true)
#  |-- recency_9block_cat_xclassVec: vector (nullable = true)
#  |-- frequency_9block_cat_xclassVec: vector (nullable = true)
#  |-- most_recent_l1_cat_xclassVec: vector (nullable = true)
#  |-- most_recent_l2_cat_xclassVec: vector (nullable = true)
#  |-- most_recent_promo_type_cat_xclassVec: vector (nullable = true)
#  |-- most_recent_platform_cat_xclassVec: vector (nullable = true)
#  |-- gender_cat_xclassVec: vector (nullable = true)
#  |-- marital_status_cat_xclassVec: vector (nullable = true)

# %%
hc = H2OContext.getOrCreate(spark)
# Out:
# Connecting to H2O server at http://10.22.142.8:54321 ... successful.
# --------------------------  ----------------------------------------------------------
# H2O cluster uptime:         54 secs
# H2O cluster timezone:       Etc/UTC
# H2O data parsing timezone:  UTC
# H2O cluster version:        3.24.0.1
# H2O cluster version age:    2 months and 19 days
# H2O cluster name:           sparkling-water-pcourbois_application_1556810695108_842945
# H2O cluster total nodes:    40
# H2O cluster free memory:    464.0 Gb
# H2O cluster total cores:    1440
# H2O cluster allowed cores:  80
# H2O cluster status:         accepting new members, healthy
# H2O connection url:         http://10.22.142.8:54321
# H2O connection proxy:
# H2O internal security:      False
# H2O API Extensions:         XGBoost, Algos, Amazon S3, AutoML, Core V3, Core V4
# Python version:             2.7.13 final
# --------------------------  ----------------------------------------------------------
# Sparkling Water Context:
#  * H2O name: sparkling-water-pcourbois_application_1556810695108_842945
#  * cluster size: 40
#  * list of used nodes:
#   (executorId, host, port)
#   ------------------------
#   (20,cerebro-worker502.snc1,54321)
#   (36,cerebro-worker492.snc1,54321)
#   (13,cerebro-worker386.snc1,54321)
#   (7,cerebro-worker437.snc1,54321)
#   (26,cerebro-worker407.snc1,54321)
#   (11,cerebro-worker398.snc1,54321)
#   (19,cerebro-worker378.snc1,54321)
#   (32,cerebro-worker422.snc1,54321)
#   (35,cerebro-worker385.snc1,54321)
#   (9,cerebro-worker387.snc1,54321)
#   (40,cerebro-worker314.snc1,54321)
#   (34,cerebro-worker406.snc1,54321)
#   (37,cerebro-worker493.snc1,54321)
#   (18,cerebro-worker281.snc1,54321)
#   (12,cerebro-worker346.snc1,54321)
#   (25,cerebro-worker350.snc1,54321)
#   (38,cerebro-worker326.snc1,54321)
#   (24,cerebro-worker347.snc1,54321)
#   (3,cerebro-worker320.snc1,54321)
#   (28,cerebro-worker250.snc1,54321)
#   (8,cerebro-worker156.snc1,54321)
#   (17,cerebro-worker139.snc1,54321)
#   (10,cerebro-worker26.snc1,54321)
#   (23,cerebro-worker242.snc1,54321)
#   (33,cerebro-worker170.snc1,54321)
#   (22,cerebro-worker497.snc1,54321)
#   (5,cerebro-worker258.snc1,54321)
#   (29,cerebro-worker358.snc1,54321)
#   (16,cerebro-worker446.snc1,54321)
#   (6,cerebro-worker47.snc1,54323)
#   (21,cerebro-worker37.snc1,54321)
#   (30,cerebro-worker4.snc1,54321)
#   (41,cerebro-worker289.snc1,54321)
#   (15,cerebro-worker70.snc1,54321)
#   (2,cerebro-worker276.snc1,54321)
#   (14,cerebro-worker336.snc1,54321)
#   (1,cerebro-worker186.snc1,54321)
#   (39,cerebro-worker138.snc1,54321)
#   (31,cerebro-worker496.snc1,54321)
#   (27,cerebro-worker132.snc1,54321)
#   ------------------------
#
#   Open H2O Flow in browser: http://10.22.142.8:54321 (CMD + click in Mac OSX)
#
#
#  * Yarn App ID of Spark application: application_1556810695108_842945

# %%
sc
# Out:
# <SparkContext master=yarn appName=PySparkShell>

# %%
h2o_train = hc.as_h2o_frame(training_final,framename="train")
h2o_test = hc.as_h2o_frame(validate_final,framename="test")

# %%
h2o_train.describe()
# Out:
# Rows:30484
# Cols:73
# <table>
# <thead>
# <tr><th>       </th><th>tenure_days_x  </th><th>recency_x    </th><th>frequency_t24m_x  </th><th>nob_t24m_x   </th><th>gp_t24m_x    </th><th>frequency_t12m_x  </th><th>nob_t12m_x   </th><th>gp_t12m_x    </th><th>local_orders_t24m_x  </th><th>shopping_orders_t24m_x  </th><th>travel_orders_t24m_x  </th><th>app_orders_t24m_x  </th><th>touch_orders_t24m_x  </th><th>web_orders_t24m_x  </th><th>is_activation_x  </th><th>unique_purchase_quarters_t24m_x  </th><th>visit_recency_x  </th><th>visit_freq_7d_x  </th><th>visit_freq_14_28d_x  </th><th>visit_freq_28_60d_x  </th><th>visit_freq_60_120d_x  </th><th>visit_freq_120_180d_x  </th><th>visit_freq_180_365d_x  </th><th>appengaged_flag90d_x  </th><th>webengaged_flag90d_x  </th><th>touchengaged_flag90d_x  </th><th>send_recency_x  </th><th>sends_7d_x   </th><th>sends_30d_x  </th><th>open_recency_x  </th><th>uniq_3day_opens_7d_x  </th><th>uniq_3day_opens_30d_x  </th><th>click_recency_x  </th><th>uniq_3day_clicks_7d_x  </th><th>uniq_3day_clicks_30d_x  </th><th>unsubscription_30d_x  </th><th>fnd_inv_csi_x  </th><th>hbw_inv_csi_x  </th><th>hna_inv_csi_x  </th><th>retail_inv_csi_x  </th><th>ttd_inv_csi_x  </th><th>charity_inv_csi_x  </th><th>total_inv_csi_x  </th><th>age_x        </th><th>email_contactable_x  </th><th>mobile_contactable_x  </th><th>deactivated   </th><th>recency_9block_cat_xclassVec0  </th><th>recency_9block_cat_xclassVec1  </th><th>frequency_9block_cat_xclassVec0  </th><th>frequency_9block_cat_xclassVec1  </th><th>most_recent_l1_cat_xclassVec0  </th><th>most_recent_l1_cat_xclassVec1  </th><th>most_recent_l2_cat_xclassVec0  </th><th>most_recent_l2_cat_xclassVec1  </th><th>most_recent_l2_cat_xclassVec2  </th><th>most_recent_l2_cat_xclassVec3  </th><th>most_recent_l2_cat_xclassVec4  </th><th>most_recent_l2_cat_xclassVec5  </th><th>most_recent_l2_cat_xclassVec6  </th><th>most_recent_promo_type_cat_xclassVec0  </th><th>most_recent_promo_type_cat_xclassVec1  </th><th>most_recent_promo_type_cat_xclassVec2  </th><th>most_recent_promo_type_cat_xclassVec3  </th><th>most_recent_platform_cat_xclassVec0  </th><th>most_recent_platform_cat_xclassVec1  </th><th>most_recent_platform_cat_xclassVec2  </th><th>gender_cat_xclassVec0  </th><th>gender_cat_xclassVec1  </th><th>marital_status_cat_xclassVec0  </th><th>marital_status_cat_xclassVec1  </th><th>marital_status_cat_xclassVec2  </th><th>marital_status_cat_xclassVec3  </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>int            </td><td>int          </td><td>int               </td><td>real         </td><td>real         </td><td>int               </td><td>real         </td><td>real         </td><td>int                  </td><td>int                     </td><td>int                   </td><td>int                </td><td>int                  </td><td>int                </td><td>int              </td><td>int                              </td><td>int              </td><td>int              </td><td>int                  </td><td>int                  </td><td>int                   </td><td>int                    </td><td>int                    </td><td>int                   </td><td>int                   </td><td>int                     </td><td>int             </td><td>int          </td><td>int          </td><td>int             </td><td>int                   </td><td>int                    </td><td>int              </td><td>int                    </td><td>int                     </td><td>int                   </td><td>real           </td><td>real           </td><td>real           </td><td>real              </td><td>real           </td><td>int                </td><td>real             </td><td>int          </td><td>int                  </td><td>int                   </td><td>int           </td><td>int                            </td><td>int                            </td><td>int                              </td><td>int                              </td><td>int                            </td><td>int                            </td><td>int                            </td><td>int                            </td><td>int                            </td><td>int                            </td><td>int                            </td><td>int                            </td><td>int                            </td><td>int                                    </td><td>int                                    </td><td>int                                    </td><td>int                                    </td><td>int                                  </td><td>int                                  </td><td>int                                  </td><td>int                    </td><td>int                    </td><td>int                            </td><td>int                            </td><td>int                            </td><td>int                            </td></tr>
# <tr><td>mins   </td><td>0.0            </td><td>0.0          </td><td>1.0               </td><td>0.25         </td><td>-10.0        </td><td>1.0               </td><td>0.25         </td><td>-160.0773    </td><td>0.0                  </td><td>0.0                     </td><td>0.0                   </td><td>0.0                </td><td>0.0                  </td><td>0.0                </td><td>1.0              </td><td>1.0                              </td><td>0.0              </td><td>0.0              </td><td>0.0                  </td><td>0.0                  </td><td>0.0                   </td><td>0.0                    </td><td>0.0                    </td><td>0.0                   </td><td>0.0                   </td><td>0.0                     </td><td>0.0             </td><td>0.0          </td><td>0.0          </td><td>0.0             </td><td>0.0                   </td><td>0.0                    </td><td>0.0              </td><td>0.0                    </td><td>0.0                     </td><td>0.0                   </td><td>0.0            </td><td>0.0            </td><td>0.0            </td><td>0.0               </td><td>0.0            </td><td>0.0                </td><td>0.0              </td><td>19.0         </td><td>0.0                  </td><td>0.0                   </td><td>0.0           </td><td>0.0                            </td><td>0.0                            </td><td>0.0                              </td><td>0.0                              </td><td>0.0                            </td><td>0.0                            </td><td>0.0                            </td><td>0.0                            </td><td>0.0                            </td><td>0.0                            </td><td>0.0                            </td><td>0.0                            </td><td>0.0                            </td><td>0.0                                    </td><td>0.0                                    </td><td>0.0                                    </td><td>0.0                                    </td><td>0.0                                  </td><td>0.0                                  </td><td>0.0                                  </td><td>0.0                    </td><td>0.0                    </td><td>0.0                            </td><td>0.0                            </td><td>0.0                            </td><td>0.0                            </td></tr>
# <tr><td>mean   </td><td>179.696463719  </td><td>174.702893321</td><td>1.03477233959     </td><td>52.632572497 </td><td>11.5419166448</td><td>1.02306127805     </td><td>51.3377870358</td><td>11.3465632889</td><td>0.803437869046       </td><td>0.20309014565           </td><td>0.0281459126099       </td><td>0.318691772733     </td><td>0.373113764598       </td><td>0.328139351791     </td><td>1.0              </td><td>1.010825351                      </td><td>144.373966671    </td><td>0.53454271093    </td><td>0.983597953025       </td><td>2.31393517911        </td><td>4.84211389581         </td><td>4.09359008004          </td><td>11.116257709           </td><td>0.266139614224        </td><td>0.161264925863        </td><td>0.209913397192          </

# %%
from h2o.estimators import H2ORandomForestEstimator
from h2o.grid.grid_search import H2OGridSearch

# %%
h2o_train["deactivated"] = h2o_train["deactivated"].asfactor()
h2o_test["deactivated"] = h2o_test["deactivated"].asfactor()
feature_names = [c for c in h2o_train.names if "_x" in c]

# %%
feature_names = [c for c in h2o_train.names if "_x" in c]

rf_grid = h2o.grid.H2OGridSearch(
                h2o.estimators.H2ORandomForestEstimator(model_id="RF_grid"
                                                    ,score_tree_interval=25
                                                    ,min_rows=1000
                                                    ,stopping_metric='auc'
                                                    ,col_sample_rate_per_tree=0.66
                                                    ,sample_rate=0.50
                                                    ,stopping_tolerance=0.02
                                                    ,ntrees=300
                                                    ,seed=28372),
                   hyper_params = {
                       "max_depth": [6, 10, 20, 30],
                   },
                grid_id='rf_grid',                      
                search_criteria={'strategy': 'RandomDiscrete', 'max_models': 4, 'seed': 3923}
        )

# %%
rf_grid.train(y="deactivated",x=feature_names
                 ,training_frame   = h2o_train,
                validation_frame = h2o_test
                ,)
# Out:
# drf Grid Build progress: |████████████████████████████████████
